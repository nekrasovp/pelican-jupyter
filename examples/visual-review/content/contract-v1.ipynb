# %% [markdown]
# # Generic notebook contract
#
# A **static** Markdown cell for visual review.

# %%
print('must not run during publication')
# Out:
# committed-code-output

# %%
generic_png_output
# Out:
# <generic PNG output>

# %%
generic_svg_output
# Out:
# <generic SVG output>

# %%
generic_table_output
# Out:
# kind
# ----
# generic

# %%
raise AssertionError('must not run during publication')
# Out:
# SyntheticError: committed error output

# %%
generic_rich_output
# Out:
# <generic rich output>
