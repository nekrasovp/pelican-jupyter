# %%
import os
from pathlib import Path
from urllib.request import urlopen
Path(os.environ['PELICAN_IPYNB_SENTINEL_MARKER']).write_text('EXECUTED')
urlopen(os.environ['PELICAN_IPYNB_SENTINEL_URL'], timeout=1).read()
# Out:
# SENTINEL_COMMITTED_OUTPUT
